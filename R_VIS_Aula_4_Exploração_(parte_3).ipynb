# %% [markdown]
# # Treino: exploração de dados
#
# Agora que vimos as partes básicas da API do Altair, vamos praticar usando os quatro conjuntos de dados a seguir.
#
# Ao explorar os dados, lembre-se dos blocos de construção que discutimos:
#
# - várias marcas: ``mark_point()``, ``mark_line()``, ``mark_tick()``, ``mark_bar()``, ``mark_area()``, ``mark_rect()``, etc.
# - várias codificações: ``x``, ``y``, ``color``, ``shape``, ``size``, ``row``, ``column``, ``text``, ``tooltip``, etc.
# - agregações: uma [Lista de agregações disponíveis](https://altair-viz.github.io/user_guide/encoding.html#binning-and-aggregation) pode ser encontrada na documentação do Altair
# - empilhamento e sobreposição (``alt.layer`` <-> ``+``, ``alt.hconcat`` <-> ``|``, ``alt.vconcat`` <-> ``&``)
#
# Comece simples e construa a partir daí. Quais codificações funcionam melhor com dados quantitativos? Com dados categóricos?
# O que você pode aprender sobre seu conjunto de dados usando essas ferramentas?

# %%
from vega_datasets import data

# %% [markdown]
# ## Gapminder
#
# Este conjunto de dados consiste em população, fertilidade e expectativa de vida ao longo do tempo em vários países ao redor do mundo.
#
# Observe que, embora você possa ser tentado a usar uma codificação temporal para o ano, aqui o ano é simplesmente um número, não uma data, e, portanto, a codificação temporal não é a melhor escolha.

# %%
gapminder = data.gapminder()
gapminder.head()
# Out:
#    year      country  cluster       pop  life_expect  fertility
# 0  1955  Afghanistan        0   8891209       30.332        7.7
# 1  1960  Afghanistan        0   9829450       31.997        7.7
# 2  1965  Afghanistan        0  10997885       34.020        7.7
# 3  1970  Afghanistan        0  12430623       36.088        7.7
# 4  1975  Afghanistan        0  14132019       38.438        7.7

# %% [markdown]
# ## Filmes
#
# O conjunto de dados de filmes contém informações sobre 3200 filmes, incluindo data de lançamento, orçamento e classificações no IMDB e Rotten Tomatoes.

# %%
movies = data.movies()
movies.head()
# Out:
#                         Title   US_Gross  Worldwide_Gross  US_DVD_Sales  \
# 0              The Land Girls   146083.0         146083.0           NaN
# 1      First Love, Last Rites    10876.0          10876.0           NaN
# 2  I Married a Strange Person   203134.0         203134.0           NaN
# 3        Let's Talk About Sex   373615.0         373615.0           NaN
# 4                        Slam  1009819.0        1087521.0           NaN
#
#    Production_Budget Release_Date MPAA_Rating  Running_Time_min Distributor  \
# 0          8000000.0  Jun 12 1998           R               NaN    Gramercy
# 1           300000.0  Aug 07 1998           R               NaN      Strand
# 2           250000.0  Aug 28 1998        None               NaN   Lionsgate
# 3           300000.0  Sep 11 1998        None               NaN   Fine Line
# 4          1000000.0  Oct 09 1998           R               NaN     Trimark
#
#                 Source Major_Genre         Creative_Type Director  \
# 0                 None        None                  None     None
# 1                 None       Drama                  None     None
# 2                 None      Comedy                  None     None
# 3                 None      Comedy                  None     None
# 4  Original Screenplay       Drama  Contemporary Fiction     None
#
#    Rotten_Tomatoes_Rating  IMDB_Rating  IMDB_Votes
# 0                     NaN          6.1      1071.0
# 1                     NaN          6.9       207.0
# 2                     NaN          6.8       865.0
# 3                    13.0          NaN         NaN
# 4                    62.0          3.4       165.0

# %% [markdown]
# # Feminicídio em Minas Gerais
#
# Dados disponíveis em: https://dados.gov.br/dados/conjuntos-dados/violencia-contra-mulher

# %%
import pandas as pd
fem = pd.read_csv("https://www.facom.ufu.br/~albertini/vis/feminicidio_mg_2023.csv", sep = ';')
fem.head()
# Out:
#    municipio_cod     municipio_fato   data_fato  mes   ano  \
# 0         310160            ALFENAS  2023-02-02    2  2023
# 1         310240  ALVORADA DE MINAS  2023-03-08    3  2023
# 2         310350           ARAGUARI  2023-04-06    4  2023
# 3         310350           ARAGUARI  2023-06-22    6  2023
# 4         310350           ARAGUARI  2023-07-06    7  2023
#
#                                  risp               rmbh tentado_consumado  \
# 0  18º Departamento - Poços de Caldas  3) Interior de MG           TENTADO
# 1          14º Departamento - Curvelo  3) Interior de MG           TENTADO
# 2        9º Departamento - Uberlândia  3) Interior de MG           TENTADO
# 3        9º Departamento - Uberlândia  3) Interior de MG           TENTADO
# 4        9º Departamento - Uberlândia  3) Interior de MG           TENTADO
#
#    qtde_vitimas
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1

# %% [markdown]
# # Violência contra a mulher em Minas Gerais

# %%
violencia = pd.read_csv("https://www.facom.ufu.br/~albertini/vis/violencia_domestica_mg_2023.csv", sep = ';')
violencia
# Out:
#        municipio_cod       municipio_fato            data_fato  mes   ano  \
# 0             310010  ABADIA DOS DOURADOS  2023-01-08 00:00:00    1  2023
# 1             310010  ABADIA DOS DOURADOS  2023-01-13 00:00:00    1  2023
# 2             310010  ABADIA DOS DOURADOS  2023-01-26 00:00:00    1  2023
# 3             310010  ABADIA DOS DOURADOS  2023-01-27 00:00:00    1  2023
# 4             310010  ABADIA DOS DOURADOS  2023-02-07 00:00:00    2  2023
# ...              ...                  ...                  ...  ...   ...
# 61531         317210         VOLTA GRANDE                45125    7  2023
# 61532         317220       WENCESLAU BRAZ                44936    1  2023
# 61533         317220       WENCESLAU BRAZ                44940    1  2023
# 61534         317220       WENCESLAU BRAZ                45025    4  2023
# 61535         317220       WENCESLAU BRAZ                45115    7  2023
#
#                                     risp               rmbh  \
# 0      10º Departamento - Patos de Minas  3) Interior de MG
# 1      10º Departamento - Patos de Minas  3) Interior de MG
# 2      10º Departamento - Patos de Minas  3) Interior de MG
# 3      10º Departamento - Patos de Minas  3) Interior de MG
# 4      10º Departamento - Patos de Minas  3) Interior de MG
# ...                                  ...                ...
# 61531     4º Departamento - Juiz de Fora  3) Interior de MG
# 61532    17º Departamento - Pouso Alegre  3) Interior de MG
# 61533    17º Departamento - Pouso Alegre  3) Interior de MG
# 61534    17º Departamento - Pouso Alegre  3) Interior de MG
# 61535    17º Departamento - Pouso Alegre  3) Interior de MG
#
#                                       natureza_delito tentado_consumado  \
# 0                                              AMEACA         CONSUMADO
# 1      DESCUMPRIMENTO DE MEDIDA PROTETIVA DE URGENCIA         CONSUMADO
# 2                                         PERSEGUICAO         CONSUMADO
# 3                                      LESAO CORPORAL         CONSUMADO
# 4                                   ACOES PREVENTIVAS         CONSUMADO
# ...                                               ...               ...
# 61531                    OUTROS INFRACOES C/ A PESSOA         CONSUMADO
# 61532                         VIAS DE FATO / AGRESSAO         CONSUMADO
# 61533                                         CALUNIA         CONSUMADO
# 61534  DESCUMPRIMENTO DE MEDIDA PROTETIVA DE URGENCIA         CONSUMADO
# 61535                                          AMEACA         CONSUMADO
#
#        qtde_vitimas
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ...             ...
# 61531             1
# 61532             1
# 61533             1
# 61534             1
# 61535             1
#
# [61536 rows x 10 columns]

# %% [markdown]
# # Série Histórica de Preços de Combustíveis e de GLP
#
# https://dados.gov.br/dados/conjuntos-dados/serie-historica-de-precos-de-combustiveis-e-de-glp

# %%
precos = pd.read_csv("http://www.facom.ufu.br/~albertini/vis/precos_combustiveis_2023_02.zip", sep =';')
precos
# Out:
#        Regiao - Sigla Estado - Sigla        Municipio  \
# 0                  SE             SP         SOROCABA
# 1                  SE             SP         SOROCABA
# 2                  SE             SP         SOROCABA
# 3                   N             AC  CRUZEIRO DO SUL
# 4                   N             AC  CRUZEIRO DO SUL
# ...               ...            ...              ...
# 472419              N             AP          SANTANA
# 472420              N             AP          SANTANA
# 472421             NE             PI         PARNAIBA
# 472422             NE             PI         PARNAIBA
# 472423             NE             PI         PARNAIBA
#
#                                                   Revenda  \
# 0       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# 1       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# 2       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# 3                                CARDINAL E OLIVEIRA LTDA
# 4                                CARDINAL E OLIVEIRA LTDA
# ...                                                   ...
# 472419                 POSTO DE COMBUSTIVEIS JARDINS LTDA
# 472420                 POSTO DE COMBUSTIVEIS JARDINS LTDA
# 472421                          MAXXI DELTA PETROLEO LTDA
# 472422                          MAXXI DELTA PETROLEO LTDA
# 472423                          MAXXI DELTA PETROLEO LTDA
#
#             CNPJ da Revenda                              Nome da Rua  \
# 0        00.003.188/0001-21                   RUA HUMBERTO DE CAMPOS
# 1        00.003.188/0001-21                   RUA HUMBERTO DE CAMPOS
# 2        00.003.188/0001-21                   RUA HUMBERTO DE CAMPOS
# 3        03.608.766/0006-56                     AVENIDA 25 DE AGOSTO
# 4        03.608.766/0006-56                     AVENIDA 25 DE AGOSTO
# ...                     ...                                      ...
# 472419   10.522.077/0012-38  RODOVIA COMANDANTE PEDRO SALVADOR DINIZ
# 472420   10.522.077/0012-38  RODOVIA COMANDANTE PEDRO SALVADOR DINIZ
# 472421   47.221.821/0001-11        AVENIDA DEPUTADO PINHEIRO MACHADO
# 472422   47.221.821/0001-11        AVENIDA DEPUTADO PINHEIRO MACHADO
# 472423   47.221.821/0001-11        AVENIDA DEPUTADO PINHEIRO MACHADO
#
#        Numero Rua Complemento          Bairro        Cep             Produto  \
# 0             306         NaN  JARDIM ZULMIRA  18061-000            GASOLINA
# 1             306         NaN  JARDIM ZULMIRA  18061-000          DIESEL S10
# 2             306         NaN  JARDIM ZULMIRA  18061-000              ETANOL
# 3            1350         NaN    25 DE AGOSTO  69980-000            GASOLINA
# 4            1350         NaN    25 DE AGOSTO  69980-000          DIESEL S10
# ...           ...         ...             ...        ...                 ...
# 472419       3005     ANEXO A   VILA AMAZONAS  68926-214              DIESEL
# 472420       3005     ANEXO A   VILA AMAZONAS  68926-214          DIESEL S10
# 472421       3570     LETRA A           PIAUÍ  64208-335            GASOLINA
# 472422       3570     LETRA A           PIAUÍ  64208-335  GASOLINA ADITIVADA
# 472423       3570     LETRA A           PIAUÍ  64208-335              ETANOL
#
#        Data da Coleta Valor de Venda  Valor de Compra Unidade de Medida  \
# 0          03/07/2023           4,87              NaN        R$ / litro
# 1          03/07/2023           4,88              NaN        R$ / litro
# 2          03/07/2023           3,27              NaN        R$ / litro
# 3          03/07/2023           6,95              NaN        R$ / litro
# 4          03/07/2023           6,85              NaN        R$ / litro
# ...               ...            ...              ...               ...
# 472419     28/12/2023           6,44              NaN        R$ / litro
# 472420     28/12/2023           6,49              NaN        R$ / litro
# 472421     27/12/2023            5,2              NaN        R$ / litro
# 472422     27/12/2023            5,2              NaN        R$ / litro
# 472423     27/12/2023           3,99              NaN        R$ / litro
#
#              Bandeira
# 0              BRANCA
# 1              BRANCA
# 2              BRANCA
# 3       VIBRA ENERGIA
# 4       VIBRA ENERGIA
# ...               ...
# 472419       IPIRANGA
# 472420       IPIRANGA
# 472421         BRANCA
# 472422         BRANCA
# 472423         BRANCA
#
# [472424 rows x 16 columns]

# %% [markdown]
# # Imposto de renda: Rendimentos Sujeitos à Tributação Exclusiva Definitiva
# Total de valores sujeitos a tributação exclusiva ou definitiva declarados pelo contribuinte por faixa de rendimento em salários mínimos.
#
# https://dados.gov.br/dados/conjuntos-dados/grandes-nmeros-do-imposto-de-renda-da-pessoa-fsica

# %%
rendimentos = pd.read_csv("http://www.facom.ufu.br/~albertini/vis/Rendimentos_Sujeitos_a_Tributacao_Exclusiva_Definitiva.zip",sep =';')
rendimentos
# Out:
#     Ano Calendário Faixa de Salários-Mínimos  13º salário  \
# 0             2020                   Até 1/2  47391,00487
# 1             2020                De 1/2 a 1  23936,76884
# 2             2020                  De 1 a 2  16986,44618
# 3             2020                  De 2 a 3  5757,257639
# 4             2020                  De 3 a 5  3979,591077
# ..             ...                       ...          ...
# 89            2011                     Todas  54941,49831
# 90            2010                     Todas  48293,97577
# 91            2009                     Todas  43845,68955
# 92            2008                     Todas   38365,3242
# 93            2007                     Todas  21580,22367
#
#    Ganho Cap. na alienação de bens ou direitos  \
# 0                                  19,88769506
# 1                                  73,21100241
# 2                                  309,4975957
# 3                                  472,1772933
# 4                                   1130,95365
# ..                                         ...
# 89                                  45480,8008
# 90                                 23952,26806
# 91                                 14722,02826
# 92                                  24919,8128
# 93                                 18039,54899
#
#    Ganho Cap. alien. bens/dir. e aplic. adquir. moeda estrang.  \
# 0                                           0,3644623
# 1                                          0,94885542
# 2                                          3,39601677
# 3                                          5,72968453
# 4                                         16,53583701
# ..                                                ...
# 89                                        442,2850051
# 90                                        452,6514422
# 91                                        232,5143072
# 92                                        440,2084225
# 93                                        380,1439628
#
#    Ganhos Cap. alienação de moeda estrangeira em espécie  \
# 0                                          0,04482014
# 1                                          0,11860999
# 2                                          0,44424512
# 3                                          0,39741982
# 4                                          1,48968059
# ..                                                ...
# 89                                                  0
# 90                                                  0
# 91                                         2,70233571
# 92                                        12,18938839
# 93                                         3,32404197
#
#    Rend. de Aplicações Financeiras Ganhos líquidos em renda variável  \
# 0                      1826,169965                       77,52293603
# 1                      2212,459138                       129,8699601
# 2                      3952,879457                       314,0638774
# 3                      3239,811178                       322,8503927
# 4                      4762,396396                       585,8774123
# ..                             ...                               ...
# 89                     51048,78456                       4728,117691
# 90                      38159,7023                       6659,262628
# 91                     33856,78227                       6329,424807
# 92                     34826,27787                       4375,884511
# 93                     23209,85643                       6538,221498
#
#    Rendimentos recebidos acumuladamente  \
# 0                           127,7375048
# 1                           432,9179713
# 2                           1012,785038
# 3                           1020,243458
# 4                           2002,808388
# ..                                  ...
# 89                           7526,89288
# 90                          4777,935709
# 91                                    0
# 92                                    0
# 93                                    0
#
#    13º salário recebido pelos dependentes  \
# 0                             76,62039828
# 1                             32,79320537
# 2                             28,62194041
# 3                             12,01197706
# 4                              9,79395049
# ..                                    ...
# 89                            138,8324828
# 90                            132,0009084
# 91                            130,3805008
# 92                            115,8490899
# 93                            77,27844613
#
#    Rendimentos recebidos acumuladamente pelos dependentes  \
# 0                                          0,96060575
# 1                                          2,46822946
# 2                                          5,55344706
# 3                                          4,93945162
# 4                                          8,16643508
# ..                                                ...
# 89                                                  0
# 90                                                  0
# 91                                                  0
# 92                                                  0
# 93                                                  0
#
#    Juros sobre capital próprio Participação nos lucros ou resultados  \
# 0                  99,39703891                           1404,398837
# 1                     100,4184                           3294,466405
# 2                  189,9977184                           7519,700016
# 3                  153,8349352                           4576,271169
# 4                  233,6255801                           4010,660341
# ..                         ...                                   ...
# 89                           0                                     0
# 90                           0                                     0
# 91                           0                                     0
# 92                           0                                     0
# 93                           0                                     0
#
#          Outros
# 0   1189,661099
# 1   1606,699506
# 2    1821,38638
# 3   1153,480376
# 4   1401,660553
# ..          ...
# 89  18685,95226
# 90  14595,46367
# 91  11983,40438
# 92  10809,43115
# 93  7618,129285
#
# [94 rows x 14 columns]
